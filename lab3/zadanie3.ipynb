# %% [markdown]
# # Odległość edycyjna (Levenshtein distance)

# %%
import numpy as np
from enum import Enum, auto

# %%
class Operations(Enum):
    SWITCH = auto()
    DELETE = auto()
    INSERT = auto()

# %%
class LevenshteinDistance:
    def __init__(self, from_word, to_word):
        self.from_word  = from_word
        self.to_word    = to_word
        self.distances  = None
        self.parents    = None
        self.reset_distances_and_parents()
        self.calculate_distances_and_parents()
        self.operations = self.create_operations()
        
    def reset_distances_and_parents(self):
        m = len(self.from_word)
        n = len(self.to_word)
        self.distances = [[0 for _ in range(n+1)] for _ in range(m+1)]
        self.parents   = [[0 for _ in range(n+1)] for _ in range(m+1)]
        for i in range(1, m+1):
            self.distances[i][0] = i
            self.parents[i][0] = (i-1, 0)
        for i in range(1, n+1):
            self.distances[0][i] = i
            self.parents[0][i] = (0, i-1)
    
    def calculate_distances_and_parents(self):
        m = len(self.from_word)
        n = len(self.to_word)
        for i in range(1, m+1):
            for j in range(1, n+1):
                cost = 1
                if self.from_word[i-1] == self.to_word[j-1]:
                    cost = 0

                self.distances[i][j] = min(self.distances[i-1][j]   + 1, 
                                           self.distances[i][j-1] + 1,
                                           self.distances[i-1][j-1] + cost)
                if self.distances[i][j] == self.distances[i-1][j] + 1:
                    self.parents[i][j] = (i-1, j)
                elif self.distances[i][j] == self.distances[i][j-1] + 1:
                    self.parents[i][j] = (i, j-1)
                else:
                    self.parents[i][j] = (i-1, j-1)
    
    def create_operations(self):
        m = len(self.from_word)
        n = len(self.to_word)
        operations = []

        while (m, n) != (0, 0):
            pm, pn = self.parents[m][n]
            d = self.distances[pm][pn]

            if d != self.distances[m][n]:
                if (m-1, n-1) == (pm, pn):
                    operations.append( (Operations.SWITCH, m-1, n-1) )
                elif (m-1, n) == (pm, pn):
                    operations.append( (Operations.DELETE, m-1) )
                else:
                    operations.append( (Operations.INSERT, m, n-1) )
            m, n = pm, pn

        operations.reverse()
        return operations
    
    def visualize(self):
        print(self.from_word, "->", self.to_word)
        idx_diff = 0
        word = self.from_word
        print(word)
        
        for operation in self.operations:
            idx1 = operation[1] + idx_diff
            if operation[0] == Operations.DELETE:
                print(f"DELETE {word[idx1]} FROM INDEX {idx1}")
                print(f"{word[:idx1]}**{word[idx1 + 1:]}")
                word = word[:idx1] + word[idx1 + 1:]
                idx_diff -= 1
            elif operation[0] == Operations.INSERT:
                idx2 = operation[2]
                print(f"INSERT {self.to_word[idx2]} TO INDEX {idx1}")
                print(f"{word[:idx1]}*{self.to_word[idx2]}*{word[idx1:]}")
                word = word[:idx1] + self.to_word[idx2] + word[idx1:]
                idx_diff += 1
            else:
                idx2 = operation[2]
                print(f"SWITCH {word[idx1]} TO {self.to_word[idx2]}")
                print(f"{word[:idx1]}*{self.to_word[idx2]}*{word[idx1 + 1:]}")
                word = word[:idx1] + self.to_word[idx2] + word[idx1 + 1:]
        print(word)
        print("ODLEGŁOŚĆ EDYCYJNA: ", len(self.operations))

# %% [markdown]
# ### 1. Zaimplementuj algorytm obliczania odległości edycyjnej w taki sposób, aby możliwe było określenie przynajmniej jednej sekwencji edycji (dodanie, usunięcie, zmiana znaku), która pozwala w minimalnej liczbie kroków, przekształcić jeden łańcuch w drugi.

# %% [markdown]
# ### 2. Na podstawie poprzedniego punktu zaimplementuj prostą wizualizację działania algorytmu, poprzez wskazanie kolejnych wersji pierwszego łańcucha, w których dokonywana jest określona zmiana. "Wizualizacja" może działać w trybie tekstowym.

# %% [markdown]
# ### 3. Przedstaw wynik działania algorytmu z p. 2 dla następujących par łańcuchów:

# %% [markdown]
# * los - kloc

# %%
LD1 = LevenshteinDistance("los", "kloc")

# %%
LD1.visualize()
# Out:
# los -> kloc
# los
# INSERT k TO INDEX 0
# *k*los
# SWITCH s TO c
# klo*c*
# kloc
# ODLEGŁOŚĆ EDYCYJNA:  2

# %% [markdown]
# ***

# %% [markdown]
# * Łódź - Lodz

# %%
LD2 = LevenshteinDistance("Łódź", "Lodz")

# %%
LD2.visualize()
# Out:
# Łódź -> Lodz
# Łódź
# SWITCH Ł TO L
# *L*ódź
# SWITCH ó TO o
# L*o*dź
# SWITCH ź TO z
# Lod*z*
# Lodz
# ODLEGŁOŚĆ EDYCYJNA:  3

# %% [markdown]
# ***

# %% [markdown]
# * kwintesencja - quintessence

# %%
LD3 = LevenshteinDistance("kwintesencja", "quintessence")

# %%
LD3.visualize()
# Out:
# kwintesencja -> quintessence
# kwintesencja
# SWITCH k TO q
# *q*wintesencja
# SWITCH w TO u
# q*u*intesencja
# INSERT s TO INDEX 7
# quintes*s*encja
# SWITCH j TO e
# quintessenc*e*a
# DELETE a FROM INDEX 12
# quintessence**
# quintessence
# ODLEGŁOŚĆ EDYCYJNA:  5

# %% [markdown]
# ***

# %% [markdown]
# * ATGAATCTTACCGCCTCG - ATGAGGCTCTGGCCCCTG

# %%
LD4 = LevenshteinDistance("ATGAATCTTACCGCCTCG", "ATGAGGCTCTGGCCCCTG")

# %%
LD4.visualize()
# Out:
# ATGAATCTTACCGCCTCG -> ATGAGGCTCTGGCCCCTG
# ATGAATCTTACCGCCTCG
# SWITCH A TO G
# ATGA*G*TCTTACCGCCTCG
# SWITCH T TO G
# ATGAG*G*CTTACCGCCTCG
# INSERT C TO INDEX 8
# ATGAGGCT*C*TACCGCCTCG
# SWITCH A TO G
# ATGAGGCTCT*G*CCGCCTCG
# INSERT G TO INDEX 11
# ATGAGGCTCTG*G*CCGCCTCG
# DELETE G FROM INDEX 14
# ATGAGGCTCTGGCC**CCTCG
# DELETE C FROM INDEX 17
# ATGAGGCTCTGGCCCCT**G
# ATGAGGCTCTGGCCCCTG
# ODLEGŁOŚĆ EDYCYJNA:  7

# %% [markdown]
# ***

# %% [markdown]
# ### 4. Zaimplementuj algorytm obliczania najdłuższego wspólnego podciągu dla pary ciągów elementów.

# %%
class LCS:
    def __init__(self, sequence1, sequence2):
        self.sequence1 = sequence1
        self.sequence2 = sequence2
        
    def calculate_LCS(self, get_array=False):
        m = len(self.sequence1)
        n = len(self.sequence2)
        LCS_array = np.zeros((m+1, n+1))
        for i in range(1, m+1):
            for j in range(1, n+1):
                if self.sequence1[i-1] == self.sequence2[j-1]:
                    LCS_array[i, j] = LCS_array[i-1, j-1] + 1
                else:
                    LCS_array[i, j] = max(LCS_array[i, j-1], LCS_array[i-1, j])
        if get_array:
            return LCS_array[m, n], LCS_array
        
        return LCS_array[m, n]

# %% [markdown]
# ### 5. Korzystając z gotowego tokenizera (np spaCy - https://spacy.io/api/tokenizer) dokonaj podziału załączonego tekstu na tokeny.

# %%
import spacy
nlp = spacy.load("pl_core_news_sm")

# %%
f = open("romeo-i-julia-700.txt", "r", encoding='utf-8')
file = nlp(f.read())
f.close()
tokens = [token.text for token in file]

# %% [markdown]
# ### 6. Stwórz 2 wersje załączonego tekstu, w których usunięto 3% losowych tokenów.

# %%
num_of_tokens_to_delete = int(len(tokens) * 3/100)

# %%
version1 = tokens.copy()
version2 = tokens.copy()
for i in range(num_of_tokens_to_delete):
    idx1 = np.random.randint(len(version1))
    while version1[idx1][0] == "\n":
        idx1 = np.random.randint(len(version1))
    version1.pop(idx1)
    
    idx2 = np.random.randint(len(version2))
    while version2[idx2][0] == "\n":
        idx2 = np.random.randint(len(version2))
    version2.pop(idx2)

# %%
file_version1 = open("version1.txt", "w", encoding='utf-8')
for i in version1:
    file_version1.write(i)
file_version1.close()

file_version2 = open("version2.txt", "w", encoding='utf-8')
for i in version2:
    file_version2.write(i)
file_version2.close()

# %% [markdown]
# ### 7. Oblicz długość najdłuższego podciągu wspólnych tokenów dla tych tekstów. Traktujemy teraz token (wyraz) jako podstawową, niepodzielną jednostkę ciągu.

# %%
lcs = LCS(version1, version2)

# %%
lcs.calculate_LCS()
# Out:
# 2542.0

# %% [markdown]
# ### 8. Korzystając z algorytmu z punktu 4 skonstruuj narzędzie, o działaniu podobnym do narzędzia diff, tzn. wskazującego w dwóch plikach linie, które się różnią. Na wyjściu narzędzia powinny znaleźć się elementy, które nie należą do najdłuższego wspólnego podciągu. Należy wskazać skąd dana linia pochodzi (< > - pierwszy/drugi plik) oraz numer linii w danym pliku. Traktujemy teraz całą linię jako podstawową, niepodzielną jednostkę ciągu.

# %%
def get_lines_from_file(file_name):
    file = open(file_name, "r", encoding='utf-8')
    lines = file.readlines()
    file.close()
    return lines

# %%
def diff(file_name_1, file_name_2):
    lines_1 = get_lines_from_file(file_name_1)
    lines_2 = get_lines_from_file(file_name_2)
    result, matrix = LCS(lines_1, lines_2).calculate_LCS(get_array=True)

    m = len(matrix)
    n = len(matrix[0])
    start = (m-1, n-1)
    indexes_1 = [True for i in range(m-1)]
    indexes_2 = [True for i in range(n-1)]

    while start[0] != 0 and start[1] != 0:
        if lines_1[start[0] - 1] == lines_2[start[1] - 1]:
            indexes_1[start[0] - 1] = False
            indexes_2[start[1] - 1] = False
            start = (start[0] - 1, start[1] - 1)
        elif matrix[start[0] - 1, start[1]] == matrix[start]:
            start = (start[0] - 1, start[1])
        else:
            start = (start[0], start[1] - 1)
            
    file_1_diffs = []
    file_2_diffs = []

    for i in range(len(indexes_1)):
        if indexes_1[i]:
            file_1_diffs.append((lines_1[i], i))

    for i in range(len(indexes_2)):
        if indexes_2[i]:
            file_2_diffs.append((lines_2[i], i))
            
    for x, y in file_1_diffs:
        print(f"plik 1, numer linii {y}: {x}")
    for x, y in file_2_diffs:
        print(f"plik 2, numer linii {y}: {x}")

# %% [markdown]
# ### 9. Przedstaw wynik działania narzędzia na tekstach z punktu 6. Zwróć uwagę na dodanie znaków przejścia do nowej linii, które są usuwane w trakcie tokenizacji.

# %%
diff("version1.txt", "version2.txt")
# Out:
# plik 1, numer linii 5: ISBN978-83-2882903-9
#
# plik 1, numer linii 12:  *MONTEKI,KAPULET—dwóchdomównieprzyjaznychsobie
#
# plik 1, numer linii 18:  *LAURENTY—ojciecfranciszkanin
#
# plik 1, numer linii 19:  *JAN—bratzzgromadzenia
#
# plik 1, numer linii 20:  *BALTAZAR—służącyRomea
#
# plik 1, numer linii 21:  *SAMSON,—słudzyKapuleta
#
# plik 1, numer linii 23:  *
#
# plik 1, numer linii 29:  *PANIKAPULET—małżonkaKapuleta
#
# plik 1, numer linii 31:  *MARTA—mamkaJulii
#
# plik 1, numer linii 32:  *Obywateleweroneńscy,różneosobypłciobojej,liczącydoprzyjaciółdomów,maski,strażwojskowaiinneosoby.
#
# plik 1, numer linii 37: Rzeczodbywasięprzezwiększączęśćsztukiw,przezczęśćpiątegoaktuwMantui.
#
# plik 1, numer linii 45: Dwarody,zacnejednakosławne—
#
# plik 1, numer linii 46: ,gdziesięrzecztarozgrywa,wWeronie,
#
# plik 1, numer linii 50: Złontychdwuwrogówwzięłobowiemżycie,
#
# plik 1, numer linii 55: Tejichmiłościprzebiegzbytbolesny
#
# plik 1, numer linii 61: Jestwnimcozłego,myusuniembłędy
#
# plik 1, numer linii 72: Placpubliczny.WchodząSamsoniGrzegorzuzbrojeniwtarczeimiecze./
#
# plik 1, numer linii 77: Dalipan,Grzegorzu,niebędziemdarli.
#
# plik 1, numer linii 82: Masięrozumieć,bobyśmybylizdziercami.
#
# plik 1, numer linii 112: Rozruchaćsiętyleznaczycoruszyćsięzmiejsca;byćwalecznymjesttostaćnieporuszenie:pojmujęwięc,żeskutkiemrozruchaniasiętwegobędzie-drapnięcie.
#
# plik 1, numer linii 117: TepsyzdomuMontekichrozruchaćmięmogątylkodostanianamiejscu.Będęjakmurkażdegomężczyznyikażdejkobietyztegodomu.
#
# plik 1, numer linii 119:
#
# plik 1, numer linii 120:
#
# plik 1, numer linii 127: Prawda,dlategotokobiety,jakonajsłabsze,sięzawszedomuru.JaodtrącęodmuruMontekich,akobietyMontekichprzyprędomuru.
#
# plik 1, numer linii 137: Mniejszamiotobędęnieubłagany.Pobiwszyludzi,wywręwściekłośćnakobietach:rzeźmiędzynimisprawię.
#
# plik 1, numer linii 152: lepiej,żesięliczyszdozwierząt;bogdybyśsięliczyłdoryb,tobyłbyśpewniesztokfiszem.nosięzainstrument,bootonadchodzidwóchdomownikówMontekiego.
#
# plik 1, numer linii 154: /WchodząAbrahamiBaltazar/
#
# plik 1, numer linii 172: GRZEGORZ
#
# plik 1, numer linii 189: Niejakchcą,alejakśmią.Jaimgębęwykrzywię;hańbaimjeślitościerpią.
#
# plik 1, numer linii 194: Skrzywiłeśsięnanas,mościpanie?
#
# plik 1, numer linii 221: Nie,mościpanie;nieskrzywiłemsięnawas,tylkoskrzywiłemsiętaksobie.
#
# plik 1, numer linii 238: Jeżelijejszukasz,jestemnawaścineusługi.pantakdobryjakiwasz.
#
# plik 1, numer linii 254:
#
# plik 1, numer linii 255: /nastroniedo/
#
# plik 1, numer linii 262: Nieinaczejlepszy.
#
# plik 1, numer linii 272: Dobądźciemieczów,jeślimacieserca.Grzegorzu,pamiętajoswoimpchnięciu.
#
# plik 1, numer linii 281: WchodziTybalt./
#
# plik 1, numer linii 287: Domnie,Benwolio!pilnujswegożycia.
#
# plik 1, numer linii 292: Przywracamtylkopokój.miecznazad
#
# plik 1, numer linii 298: Zgołymorężempokój?Nienawidzę
#
# plik 1, numer linii 308: Hola!!pałek!Dalejponich!
#
# plik 1, numer linii 328: Iszydnieswojąklingąmiurąga.
#
# plik 1, numer linii 346: /WchodziKsiążęz./
#
# plik 1, numer linii 351: Zapamiętaliniesfornipoddani,
#
# plik 1, numer linii 352: Bezcześcicielebratniejstali!Cóżto,
#
# plik 1, numer linii 353: Czynie?Ludzieczyzwierzęta,
#
# plik 1, numer linii 356: karątorturwypuśćcienatychmiast
#
# plik 1, numer linii 358: Iposłuchajcietego,coniniejszym
#
# plik 1, numer linii 360: Domowestarcia,marnychsłówzrodzone
#
# plik 1, numer linii 362: Trzykroćjużspokójmiastazakłóciły,
#
# plik 1, numer linii 363: Takżewiekiemizasługą
#
# plik 1, numer linii 372: Ty,Kapulecie,pójdzieszzemnąrazem;
#
# plik 1, numer linii 373: Tyzaś,Monteki,przyjdzieszpopołudniu
#
# plik 1, numer linii 374: Naratusz,ciwtymwzględzie
#
# plik 1, numer linii 375: Dalszamawolabędzie.
#
# plik 1, numer linii 376: razwzywamwszystkichtuobecnych
#
# plik 1, numer linii 384: Ktowszcząłtęnowązwadę?Mów,synowcze,
#
# plik 1, numer linii 385: Byłżeśtuwtedy,gdysięzaczęło?
#
# plik 1, numer linii 392: Dobyłembroni,ichrozdzielić:
#
# plik 1, numer linii 394: Ihardemiwuszywyzwanie,
#
# plik 1, numer linii 395: Jąłsięwywijaćnimisiecpowietrze,
#
# plik 1, numer linii 399: Większyludzi;zobustronwalczono,
#
# plik 1, numer linii 405: LeczgdzieżRomeożeśgodzisiaj?
#
# plik 1, numer linii 406: Jakżesięcieszę,żeniebyłtymstarciu.
#
# plik 1, numer linii 411: Godzinąpierwej,nimwspaniałesłońce
#
# plik 1, numer linii 415: Kupołudniowiodnaszegomiasta.
#
# plik 1, numer linii 416: Tam,jużtakrano,synwaszsięprzechadzał.
#
# plik 1, numer linii 419: Iwnajciemniejszejukryłsięgęstwinie.
#
# plik 1, numer linii 421: Mierzącwłasnym(sercenaszebowiem
#
# plik 1, numer linii 431: Łzamiporannąmnożącegorosę,
#
# plik 1, numer linii 433: Aliściledwonanajdalszymwschodzie
#
# plik 1, numer linii 438: przedjasnymdniablaskiem
#
# plik 1, numer linii 440: Wczarneduszajegozajdzie,
#
# plik 1, numer linii 446: Szanownystryju,znasz–żepowódtego?
#
# plik 1, numer linii 461: Wybadywałemisam,iprzezdrugich,
#
# plik 1, numer linii 467: Ipełnośćswojąrozwinąłprzedsłońcem.
#
# plik 1, numer linii 468: Gdybyśmymoglidojśćtroskzarodka,
#
# plik 1, numer linii 477: Wyrwęmuzpiersicierpieniatajone.
#
# plik 1, numer linii 482: wtejsprawie,conamsercerani,
#
# plik 1, numer linii 485: /WychodząMontekiiPani./
#
# plik 1, numer linii 490: Dzieńdobry,bracie.
#
# plik 1, numer linii 500: Dziewiątabiładopiero.
#
# plik 1, numer linii 505:                         Jaknudnie
#
# plik 1, numer linii 517: Nieposiadanietego,cojeskraca.
#
# plik 1, numer linii 527:                         Brakjej.
#
# plik 1, numer linii 532:                         Jakto?brakmiłości
#
# plik 1, numer linii 542: !Czemuż,zdającniebianką,
#
# plik 1, numer linii 543: Miłośćjestwgruncietaksrogątyranką?
#
# plik 1, numer linii 548: Niestety!,zzasłonąnaskroni,
#
# plik 1, numer linii 550: Gdzieżdziśjeśćbędziem?AchByłtupodobno
#
# plik 1, numer linii 553: Owyniepojętedziwa
#
# plik 1, numer linii 555: Cośnarodzonezniczego!Pieszczoto
#
# plik 1, numer linii 556: Odpychająca!Poważnapustoto!
#
# plik 1, numer linii 559: Śniebezsnu!Takątowsobiezawiłość,
#
# plik 1, numer linii 560: Takąniełącznośćłączymojamiłość.
#
# plik 1, numer linii 583: Miłościnawetprzezodbitkędziała?
#
# plik 1, numer linii 589: Todym,cozparąsięunosi;
#
# plik 1, numer linii 590: Tożar,cowokuszczęśliwego;
#
# plik 1, numer linii 591: Morzełez,wktórymnieszczęśliwytonie.
#
# plik 1, numer linii 593: Żółciątrawiącąizbawczymbalsamem.
#
# plik 1, numer linii 607: Ach!janiejestemtu,jestemsobą;
#
# plik 1, numer linii 613: Kogóżtokochasz?
#
# plik 1, numer linii 616: ROMEO
#
# plik 1, numer linii 619: Mam–żewrazjęczyćimówić
#
# plik 1, numer linii 625: mikluczdaćdotegoproblemu,
#
# plik 1, numer linii 629:
#
# plik 1, numer linii 632: Pisaćtestament:będzie–żtowezwanie
#
# plik 1, numer linii 633: Dobredla,ktojestwtakzłymstanie
#
# plik 1, numer linii 639:                         Celniemmierzył,
#
# plik 1, numer linii 640: Gdymtopomyślał,nimeśmipowierzył.
#
# plik 1, numer linii 651:                         Wpięknycelnajłatwiej.
#
# plik 1, numer linii 657: Kupida;onamanaturęDiany;
#
# plik 1, numer linii 659: Grotówmiłościwcalesięnieboi
#
# plik 1, numer linii 660: Szydziznawałuzaklęć;
#
# plik 1, numer linii 664: Żekiedyumrze,dogrobuzniązstąpi
#
# plik 1, numer linii 665: Całe,któregotakskąpi.
#
# plik 1, numer linii 678: Zbytona,zbytmądrazarazem;
#
# plik 1, numer linii 697:                         oczomwolność
#
# plik 2, numer linii 5: ISBN978-83-288-2903-9
#
# plik 2, numer linii 12:  *MONTEKIKAPULET—naczelnicydwóchdomównieprzyjaznychsobie
#
# plik 2, numer linii 18:  *LAURENTYojciecfranciszkanin
#
# plik 2, numer linii 19:  *JAN—bratztegożzgromadzenia
#
# plik 2, numer linii 20:  *BALTAZARsłużącyRomea
#
# plik 2, numer linii 21:  *SAMSON,GRZEGORZ—słudzyKapuleta
#
# plik 2, numer linii 23:  *APTEKARZ
#
# plik 2, numer linii 29:  *PANIKAPULETmałżonkaKapuleta
#
# plik 2, numer linii 31:  *MARTA—Julii
#
# plik 2, numer linii 32:  *Obywateleweroneńscy,różneosobypłciobojej,liczącysiędoprzyjaciółobudomów,maski,strażwojskowaiinneosoby.
#
# plik 2, numer linii 37: RzeczodbywasięprzezwiększączęśćsztukiwWeronie,przezczęśćpiątegoaktuwMantui.
#
# plik 2, numer linii 45: Dwarody,zacnejednakoisławne—
#
# plik 2, numer linii 46: Tam,gdziesięrzecztarozgrywa,wWeronie,
#
# plik 2, numer linii 50: Ztychdwuwrogówwzięłobowiemżycie,
#
# plik 2, numer linii 55: ichmiłościprzebiegzbytbolesny
#
# plik 2, numer linii 61: Jestwnimcozłego,myusuniembłędy…
#
# plik 2, numer linii 72: /Placpubliczny.SamsoniGrzegorzuzbrojenitarczeimiecze./
#
# plik 2, numer linii 77: Dalipan,Grzegorzu,niebędziemdarlipierza.
#
# plik 2, numer linii 82: Masię,bobyśmybylizdziercami.
#
# plik 2, numer linii 112: Rozruchaćsiętyleznaczycoruszyćsięzmiejsca;byćwalecznymjesttostaćnieporuszenie:więc,żeskutkiemrozruchaniasiętwego-drapnięcie.
#
# plik 2, numer linii 115: SAMSON
#
# plik 2, numer linii 117: TepsyzdomuMontekichrozruchaćmięmogądostanianamiejscu.Będęjakmurdlakażdegomężczyznyikażdejkobietydomu.
#
# plik 2, numer linii 120: GRZEGORZ
#
# plik 2, numer linii 127: Prawda,dlategotokobietyjakonajsłabsze,tuląsięzawszedomuru.JaodtrącęodmuruludziMontekich,akobietyMontekichprzyprędomuru.
#
# plik 2, numer linii 137: Mniejszamioto,będęnieubłagany.Pobiwszyludzi,wywręwściekłośćnakobietach:rzeźmiędzynimisprawię.
#
# plik 2, numer linii 152: Tymlepiej,żesięliczyszdozwierząt;bogdybyśsięliczyłdoryb,tobyłbyśpewniesztokfiszem.WeźnosięzainstrumentbootonadchodzidwóchdomownikówMontekiego.
#
# plik 2, numer linii 154: /WchodząAbrahamiBaltazar./
#
# plik 2, numer linii 170:
#
# plik 2, numer linii 189: Niejakchcą,alejakśmią.Jaimwykrzywię;hańbaim,jeślitościerpią.
#
# plik 2, numer linii 194: Skrzywiłeśsięnanasmościpanie?
#
# plik 2, numer linii 221: Nie,mościpanie;nieskrzywiłemsięnawas,tylkoskrzywiłemsiętaksobie
#
# plik 2, numer linii 238: Jeżelijejszukasz,tojestemnawaścineusługi.Mójpantakdobryjakiwasz.
#
# plik 2, numer linii 253: GRZEGORZ
#
# plik 2, numer linii 255: /nastroniedoSamsona/
#
# plik 2, numer linii 262: Nie;lepszy.
#
# plik 2, numer linii 272: Dobądźciemieczów,jeślimacieserca.Grzegorzu,pamiętajopchnięciu.
#
# plik 2, numer linii 281: /WchodziTybalt/
#
# plik 2, numer linii 287: Domnie,!pilnujswegożycia.
#
# plik 2, numer linii 292: Przywracamtylko.Włóżmiecznazad
#
# plik 2, numer linii 298: Zgołymorężempokój?
#
# plik 2, numer linii 308: Hola!berdyszów!pałek!Dalejponich!
#
# plik 2, numer linii 328: Iszydnieklingąmiurąga.
#
# plik 2, numer linii 346: /WchodziKsiążęzorszakiem./
#
# plik 2, numer linii 351: niesfornipoddani,
#
# plik 2, numer linii 352: Bezcześcicielestali!Cóżto,
#
# plik 2, numer linii 353: Czyniesłyszycie?Ludzieczyzwierzęta,
#
# plik 2, numer linii 356: Podkarąwypuśćcienatychmiast
#
# plik 2, numer linii 358: Iposłuchajcietego,niniejszym
#
# plik 2, numer linii 360: Domowestarcia,zmarnychsłówzrodzone
#
# plik 2, numer linii 362: Trzykroćspokójzakłóciły,
#
# plik 2, numer linii 363: Takżepoważniizasługą
#
# plik 2, numer linii 372: Ty,Kapulecie,zemnąrazem;
#
# plik 2, numer linii 373: Tyzaś,,przyjdzieszpopołudniu
#
# plik 2, numer linii 374: Naratusz,gdziecidokładniewtymwzględzie
#
# plik 2, numer linii 375: Dalszamawolaoznajmionabędzie.
#
# plik 2, numer linii 376: Jeszczerazwzywamwszystkichtuobecnych
#
# plik 2, numer linii 384: Ktowszcząłnowązwadę?Mów,synowcze,
#
# plik 2, numer linii 385: Byłżeśtuwtedy,gdysiętozaczęło?
#
# plik 2, numer linii 392: Dobyłembroni,abyichrozdzielić:
#
# plik 2, numer linii 394: Ihardezionącmiwuszywyzwanie,
#
# plik 2, numer linii 395: Jąłsięwywijaćnimsiecpowietrze,
#
# plik 2, numer linii 399: Większytłumludzizobustronwalczono,
#
# plik 2, numer linii 405: LeczgdzieżRomeo?Widziałgodzisiaj?
#
# plik 2, numer linii 406: Jakżesięcieszę,żeniebyłwtymstarciu.
#
# plik 2, numer linii 411: Godzinąpierwej,nimsłońce
#
# plik 2, numer linii 415: Kupołudniowinaszegomiasta.
#
# plik 2, numer linii 416: Tam,jużtakrano,synwaszsię.
#
# plik 2, numer linii 419: Iwnajciemniejszejukryłgęstwinie.
#
# plik 2, numer linii 421: Mierzącmymwłasnym(sercenaszebowiem
#
# plik 2, numer linii 431: Łzamiporannąrosę,
#
# plik 2, numer linii 433: ledwonanajdalszymwschodzie
#
# plik 2, numer linii 438: Zasłaniałoknaprzedjasnymdniablaskiem
#
# plik 2, numer linii 440: Wczarnebezdrożaduszajegozajdzie,
#
# plik 2, numer linii 446: Szanownystryju,znasz–żepowódtego
#
# plik 2, numer linii 461: Wybadywałemisam,iprzez,
#
# plik 2, numer linii 467: Ipełnośćswojąrozwinąłprzed.
#
# plik 2, numer linii 468: Gdybyśmymoglidojśćtychtroskzarodka,
#
# plik 2, numer linii 477: Wyrwęzpiersicierpienia.
#
# plik 2, numer linii 482: Obyśwtejsprawie,conamrani,
#
# plik 2, numer linii 485: /WychodząMontekiiPaniMonteki./
#
# plik 2, numer linii 490: Dzieńdobrybracie.
#
# plik 2, numer linii 500: Dziewiątabiładopiero
#
# plik 2, numer linii 505:                         nudnie
#
# plik 2, numer linii 517: Nieposiadanietego,coje.
#
# plik 2, numer linii 527:                         Brak.
#
# plik 2, numer linii 532:                         Jakto?brakmiłości?
#
# plik 2, numer linii 542: Niestety!Czemuż,zdającsięniebianką,
#
# plik 2, numer linii 543: Miłośćjestwgrunciesrogątyranką?
#
# plik 2, numer linii 548: Niestety!Czemuż,zzasłonąnaskroni,
#
# plik 2, numer linii 550: Gdzieżdziśjeśćbędziem?Ach!Byłtupodobno
#
# plik 2, numer linii 553: O!wysprzecznościniepojętedziwa!
#
# plik 2, numer linii 555: Cośnarodzonezniczego!
#
# plik 2, numer linii 556: Odpychająca!Poważna!
#
# plik 2, numer linii 559: ŚniebezsnuTakątowsobiezawiłość,
#
# plik 2, numer linii 560: Takąniełącznośćłączymojamiłość
#
# plik 2, numer linii 583: nawetprzezodbitkędziała?
#
# plik 2, numer linii 589: Todym,cozparąwestchnieńsięunosi;
#
# plik 2, numer linii 590: Tożar,cookuszczęśliwegopłonie;
#
# plik 2, numer linii 591: Morzełez,wktórymtonie.
#
# plik 2, numer linii 593: Żółciąizbawczymbalsamem
#
# plik 2, numer linii 607: Ach!janiejestemtu,niejestemsobą;
#
# plik 2, numer linii 612:
#
# plik 2, numer linii 613: Kogóżtokochasz?mów!
#
# plik 2, numer linii 619: Mam–żewrazjęczyćimówić?
#
# plik 2, numer linii 625: Tylkomikluczdaćdotegoproblemu,
#
# plik 2, numer linii 629: ROMEO
#
# plik 2, numer linii 632: Pisaćtestament:będzie–żwezwanie
#
# plik 2, numer linii 633: dlatego,ktojestwtakzłymstanie?
#
# plik 2, numer linii 639:                         Celniem,
#
# plik 2, numer linii 640: Gdymtopomyślałmipowierzył.
#
# plik 2, numer linii 651:                         Wpięknynajłatwiej.
#
# plik 2, numer linii 657: KupidaonamanaturęDiany;
#
# plik 2, numer linii 659: Grotówmiłościwcalesięnieboi;
#
# plik 2, numer linii 660: Szydziznawałuzaklęćoblężniczych;
#
# plik 2, numer linii 664: Żekiedyumrze,dogrobuniązstąpi
#
# plik 2, numer linii 665: Całebogactwo,któregotakskąpi.
#
# plik 2, numer linii 678: Zbytonapiękna,zbytmądrazarazem;
#
# plik 2, numer linii 697:                         Dającoczomwolność
